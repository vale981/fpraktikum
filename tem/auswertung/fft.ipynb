# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from utility import *

# %%
# %matplotlib inline
images = ['../messungen/Fokus_Latex/auswertung/Fokus0.jpg', '../messungen/Fokus_Latex/auswertung/Fokus20.jpg', '../messungen/Fokus_Latex/auswertung/Fokus-20.jpg', ]
labels = ['Fokus', 'Unterfokus', 'Uberfokus']

plot_images_fft(images, labels, save=('latex_fft', 'latex_kugel', (10, 10)))
# Out:
# (<Figure size 720x720 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f1d16006640>,
# ...
#        dtype=object))
